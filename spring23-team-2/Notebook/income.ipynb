# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot as plt
df = pd.read_csv("Household_Income.csv")
dfb = pd.read_csv("numWorkers_Income.csv")
dfc = pd.read_csv("race_Income.csv")
dfc.dtypes
# Out:
# Label (Grouping)                                         object
# Census Tract 64 Number of Estimate                      float64
# Census Tract 64 Percent Distribution Estimate           float64
# Census Tract 64 Mean income Estimate                    float64
# Census Tract 102.01 Number of Estimate                  float64
# Census Tract 102.01 Percent Distribution of Estimate    float64
# Census Tract 102.01 Mean income Estimate                float64
# Census Tract 102.02 Number of Estimate                  float64
# Census Tract 102.02 Percent Distribution of Estimate    float64
# Census Tract 102.02 Mean income Estimate                float64
# Census Tract 105 Number of Estimate                     float64
# Census Tract 105 Percent Distribution of Estimate       float64
# Census Tract 105 Mean income Estimate                   float64
# Census Tract 110.01 Number of Estimate                  float64
# Census Tract 110.01 Percent Distribution of Estimate    float64
# ...

# %%
df1 = df[["Label (Grouping)","Census Tract 64 Mean income Estimate","Census Tract 102.01 Mean income Estimate",'Census Tract 102.02 Mean income Estimate','Census Tract 105 Mean income Estimate','Census Tract 110.01 Mean income Estimate','Census Tract 110.02 Mean income Estimate']]
df1.plot.barh(x = 'Label (Grouping)').set_title("Average income of household with differece source")
# Out:
# Text(0.5, 1.0, 'Average income of household with differece source')

# %%
df2 = dfb[["Label (Grouping)","Census Tract 64 Number of Estimate",'Census Tract 102.01 Number of Estimate','Census Tract 102.02 Number of Estimate','Census Tract 105 Number of Estimate',"Census Tract 110.01 Mean income Estimate","Census Tract 110.02 Number of Estimate"]]
df2.plot.barh(x="Label (Grouping)").set_title("Number of households with different number of workers")
# Out:
# Text(0.5, 1.0, 'Number of households with different number of workers')

# %%
df3 = dfc[["Label (Grouping)","Census Tract 64 Mean income Estimate","Census Tract 102.01 Mean income Estimate",'Census Tract 102.02 Mean income Estimate','Census Tract 105 Mean income Estimate','Census Tract 110.01 Mean income Estimate','Census Tract 110.02 Mean income Estimate']]
df3.plot.barh(x = 'Label (Grouping)',legend = False).set_title("Average income between races")
# Out:
# Text(0.5, 1.0, 'Average income between races')
