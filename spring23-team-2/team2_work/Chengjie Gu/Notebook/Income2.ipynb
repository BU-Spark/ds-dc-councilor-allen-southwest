# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot as plt
PATH = "../Deliverable2/ChengjieData2/"

dfa = pd.read_csv(PATH+"Tract 64 Income Estimate(2010-2020).csv")
dfb = pd.read_csv(PATH+"Tract 105 Income Estimate(2010-2020).csv")
df = pd.read_csv(PATH+"Income Estimate(2010-2020).csv")
df
# Out:
#     Year  HOUSEHOLD INCOME  All households  With earnings  \
# 0   2010               NaN           39174          47984
# 1   2011               NaN           34597          41944
# 2   2012               NaN           34488          43900
# 3   2013               NaN           31835          40108
# 4   2014               NaN           29321          36463
# 5   2015               NaN           38450          52622
# 6   2016               NaN           47632          66620
# 7   2017               NaN           44280          63380
# 8   2018               NaN           66551          89227
# 9   2019               NaN           65938          91792
# 10  2020               NaN           70817          96626
# 11  2010               NaN           77633          85845
# 12  2011               NaN           81546          91663
# 13  2012               NaN           84809          95391
# 14  2013               NaN           85047          95244
# ...

# %%
df0 = df.pivot(index='Year', columns='Tract District', values='All households')
df0.plot(title="Household Income")
# Out:
# <AxesSubplot:title={'center':'Household Income'}, xlabel='Year'>

# %%
df1 = df.pivot(index='Year', columns='Tract District', values='Black or African American')
df1.plot(title="Black or African American Income")
# Out:
# <AxesSubplot:title={'center':'Black or African American Income'}, xlabel='Year'>

# %%
df2 = df.loc[df['Tract District'] == 'Tract105']
df2.plot(x = "Year",y=["White","Black or African American",'White alone, not Hispanic or Latino','Asian'],title="Household in Income in Tract105")
df3 = df.loc[df['Tract District'] == 'Tract64']
df3.plot(x = "Year",y=["White","Black or African American","White alone, not Hispanic or Latino",'Asian'],title="Household in Income in Tract64")
# Out:
# <AxesSubplot:title={'center':'Household in Income in Tract64'}, xlabel='Year'>
