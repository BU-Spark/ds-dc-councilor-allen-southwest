# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df_pd_2013 = pd.read_csv('PD_2013.csv')

df_pd_2014 = pd.read_csv('PD_2014.csv')

df_pd_2015 = pd.read_csv('PD_2015.csv')

df_pd_2016 = pd.read_csv('PD_2016.csv')

df_pd_2017 = pd.read_csv('PD_2017.csv')

df_pd_2018 = pd.read_csv('PD_2018.csv')

df_pd_2019 = pd.read_csv('PD_2019.csv')

df_pd_2020 = pd.read_csv('PD_2020.csv')

df_pd_2021 = pd.read_csv('PD_2021.csv')

# %% [markdown]
# #### Data preprocessing

# %%
df_pd_2017.head()
# Out:
#                                     Label (Grouping)  \
# 0                                             Total:
# 1      Income in the past 12 months below poverty...
# 2                                 With a disability:
# 3                                    In labor force:
# 4                                    In Armed Forces
#
#   Block Group 1, Census Tract 64, District of Columbia, District of Columbia!!Estimate  \
# 0                                              1,053
# 1                                                514
# 2                                                247
# 3                                                  0
# 4                                                  0
#
#    Block Group 2, Census Tract 64, District of Columbia, District of Columbia!!Estimate  \
# 0                                                547
# 1                                                210
# 2                                                 53
# ...

# %%
# assuming the data is stored in a dataframe called 'df'
new_column_names_2013 =  ['Label', 'BG1_CT64_2013', 'BG2_CT64_2013', 'BG1_CT102_2013', 'BG2_CT102_2013', 'BG1_CT105_2013', 'BG2_CT105_2013', 'BG1_CT110_2013', 'BG2_CT110_2013', 'BG3_CT110_2013', 'BG4_CT110_2013']                                                   #['Label','BG1_CT64', 'BG2_CT64', 'BG1_CT102', 'BG2_CT102', 'BG1_CT105', 'BG2_CT105', 'BG1_CT110', 'BG2_CT110', 'BG3_CT110', 'BG4_CT110']
df_pd_2013.columns = new_column_names_2013

new_column_names_2014 =   ['Label', 'BG1_CT64_2014', 'BG2_CT64_2014', 'BG1_CT102_2014', 'BG2_CT102_2014', 'BG1_CT105_2014', 'BG2_CT105_2014', 'BG1_CT110_2014', 'BG2_CT110_2014', 'BG3_CT110_2014', 'BG4_CT110_2014']
                                                                                                                                                                                                                                            #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT102', 'BG2_CT102', 'BG1_CT105', 'BG2_CT105', 'BG1_CT110', 'BG2_CT110', 'BG3_CT110', 'BG4_CT110']
df_pd_2014.columns = new_column_names_2014

new_column_names_2015 =   ['Label', 'BG1_CT64_2015', 'BG2_CT64_2015', 'BG1_CT102_2015', 'BG2_CT102_2015', 'BG1_CT105_2015', 'BG2_CT105_2015', 'BG1_CT110_2015', 'BG2_CT110_2015', 'BG3_CT110_2015', 'BG4_CT110_2015']                                                                  #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT102', 'BG2_CT102', 'BG1_CT105', 'BG2_CT105', 'BG1_CT110', 'BG2_CT110', 'BG3_CT110', 'BG4_CT110']
df_pd_2015.columns = new_column_names_2015

new_column_names_2016 = ['Label', 'BG1_CT64_2016', 'BG2_CT64_2016', 'BG1_CT102_2016', 'BG2_CT102_2016', 'BG1_CT105_2016', 'BG2_CT105_2016', 'BG1_CT110_2016', 'BG2_CT110_2016', 'BG3_CT110_2016', 'BG4_CT110_2016']                     #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT102', 'BG2_CT102', 'BG1_CT105', 'BG2_CT105', 'BG1_CT110', 'BG2_CT110', 'BG3_CT110', 'BG4_CT110']
df_pd_2016.columns = new_column_names_2016

new_column_names_2017 = ['Label', 'BG1_CT64_2017', 'BG2_CT64_2017', 'BG1_CT102_2017', 'BG2_CT102_2017', 'BG1_CT105_2017', 'BG2_CT105_2017', 'BG1_CT110_2017', 'BG2_CT110_2017', 'BG3_CT110_2017', 'BG4_CT110_2017']    #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT102', 'BG2_CT102', 'BG1_CT105', 'BG2_CT105', 'BG1_CT110', 'BG2_CT110', 'BG3_CT110', 'BG4_CT110']
df_pd_2017.columns = new_column_names_2017

new_column_names_2018 = ['Label', 'BG1_CT64_2018', 'BG2_CT64_2018', 'BG1_CT102_2018', 'BG2_CT102_2018', 'BG1_CT105_2018', 'BG2_CT105_2018', 'BG1_CT110_2018', 'BG2_CT110_2018', 'BG3_CT110_2018', 'BG4_CT110_2018'] #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT102', 'BG2_CT102', 'BG1_CT105', 'BG2_CT105', 'BG1_CT110', 'BG2_CT110', 'BG3_CT110', 'BG4_CT110']
df_pd_2018.columns = new_column_names_2018

new_column_names_2019 =  ['Label', 'BG1_CT64_2019', 'BG2_CT64_2019', 'BG1_CT102_2019', 'BG2_CT102_2019', 'BG1_CT105_2019', 'BG2_CT105_2019', 'BG1_CT110_2019', 'BG2_CT110_2019', 'BG3_CT110_2019', 'BG4_CT110_2019']                                                                                                                                                                                                      #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT102', 'BG2_CT102', 'BG1_CT105', 'BG2_CT105', 'BG1_CT110', 'BG2_CT110', 'BG3_CT110', 'BG4_CT110']
df_pd_2019.columns = new_column_names_2019

new_column_names_2020 =  ['Label', 'BG1_CT64_2020', 'BG2_CT64_2020', 'BG1_CT105_2020', 'BG2_CT105_2020', 'BG3_CT105_2020', 'BG4_CT105_2020', 'BG5_CT105_2020']                                                                                                                                                                                                                                   #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT105', 'BG2_CT105', 'BG3_CT105', 'BG4_CT105', 'BG5_CT105']
df_pd_2020.columns = new_column_names_2020

new_column_names_2021 =  ['Label', 'BG1_CT64_2021', 'BG2_CT64_2021', 'BG1_CT105_2021', 'BG2_CT105_2021', 'BG3_CT105_2021', 'BG4_CT105_2021', 'BG5_CT105_2021']                                                                                                                                                                                   #['Label', 'BG1_CT64', 'BG2_CT64', 'BG1_CT105', 'BG2_CT105', 'BG3_CT105', 'BG4_CT105', 'BG5_CT105']
df_pd_2021.columns = new_column_names_2021

# %%
df_pd_2013['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2014['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2015['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2016['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2017['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2018['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2019['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2020['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')
df_pd_2021['Label'] = df_pd_2013['Label'].str.replace('\xa0\xa0\xa0\xa0', '')

# %%
list_y = [df_pd_2013,df_pd_2014,df_pd_2015,df_pd_2016,df_pd_2017,df_pd_2018,df_pd_2019,df_pd_2020,df_pd_2021]

# Define a function to modify the label column
def modify_label(label, row_num):
    if row_num == 2:
        label = label + ' (below poverty level)'
    elif row_num in range(3, 9):
        label = label + ' (disability below poverty level)'
    elif row_num == 9:
        label = label + ' (below poverty level)'
    elif row_num in range(10, 16):
        label = label + ' (no disability below poverty level)'
    elif row_num == 17:
        label = label + ' (above poverty level)'
    elif row_num in range(18, 24):
        label = label + ' (disability above poverty level)'
    elif row_num == 24:
        label = label + ' (above poverty level)'
    elif row_num in range(25, 31):
        label = label + ' (no disability above poverty level)'
    return label

# Apply the modify_label function to the Label column
for x in list_y:
    for row_num, label in enumerate(x['Label']):
        x.loc[row_num, 'Label'] = modify_label(label, row_num)

# %%
# Merge dataframes starting from 2013 to 2021
df_merged = df_pd_2013.merge(df_pd_2014, on='Label').merge(df_pd_2015, on='Label').merge(df_pd_2016, on='Label').merge(df_pd_2017, on='Label').merge(df_pd_2018, on='Label').merge(df_pd_2019, on='Label').merge(df_pd_2020, on='Label').merge(df_pd_2021, on='Label')

# %%
df_merged
# Out:
#                                                 Label  BG1_CT64_2013  \
# 0                                              Total:            730
# 1   Income in the past 12 months below poverty level:            391
# 2            With a disability: (below poverty level)            200
# 3    In labor force: (disability below poverty level)              0
# 4    In Armed Forces (disability below poverty level)              0
# 5          Civilian: (disability below poverty level)              0
# 6           Employed (disability below poverty level)              0
# 7         Unemployed (disability below poverty level)              0
# 8   Not in labor force (disability below poverty l...            200
# 9                No disability: (below poverty level)            191
# 10  In labor force: (no disability below poverty l...            119
# 11  In Armed Forces (no disability below poverty l...              0
# 12      Civilian: (no disability below poverty level)            119
# ...

# %% [markdown]
# #### Labels filtering

# %%
df_merged_copy = df_merged.copy()
df_merged_copy.loc[30]['Label']
# Out:
# 'Not in labor force (no disability above poverty level)'

# %%
# Define the list of labels to keep
labels_to_keep_2 = ['Unemployed (no disability below poverty level)',
                    'In labor force: (no disability below poverty level)',
                    'In labor force: (disability above poverty level)',
                    'Unemployed (disability above poverty level)',
                 'In labor force: (disability below poverty level)',
                  'In labor force: (no disability above poverty level)',
                   'Unemployed (disability below poverty level)',
                   'Unemployed (no disability above poverty level)']

# Create a boolean mask based on the 'Label' column
mask_2 = df_merged_copy['Label'].isin(labels_to_keep_2)

# Filter the rows of df_merged using the mask
df_merged_copy_new = df_merged_copy[mask_2]

# %%
df_merged_copy_new = df_merged_copy_new.reset_index(drop = True)
df_merged_copy_new
# Out:
#                                                Label  BG1_CT64_2013  \
# 0   In labor force: (disability below poverty level)              0
# 1        Unemployed (disability below poverty level)              0
# 2  In labor force: (no disability below poverty l...            119
# 3     Unemployed (no disability below poverty level)             49
# 4   In labor force: (disability above poverty level)             43
# 5        Unemployed (disability above poverty level)              9
# 6  In labor force: (no disability above poverty l...            140
# 7     Unemployed (no disability above poverty level)              0
#
#    BG2_CT64_2013  BG1_CT102_2013 BG2_CT102_2013 BG1_CT105_2013 BG2_CT105_2013  \
# 0             10               2              0             22              0
# 1             10               0              0              4              0
# 2             64              14             40             16             28
# ...

# %%
df_merged_copy_new.iloc[0:,1:] = df_merged_copy_new.iloc[0:,1:].replace(',', '', regex=True).astype(int)

# %%
df_merged_copy_new
# Out:
#                                                Label  BG1_CT64_2013  \
# 0   In labor force: (disability below poverty level)              0
# 1        Unemployed (disability below poverty level)              0
# 2  In labor force: (no disability below poverty l...            119
# 3     Unemployed (no disability below poverty level)             49
# 4   In labor force: (disability above poverty level)             43
# 5        Unemployed (disability above poverty level)              9
# 6  In labor force: (no disability above poverty l...            140
# 7     Unemployed (no disability above poverty level)              0
#
#    BG2_CT64_2013  BG1_CT102_2013  BG2_CT102_2013  BG1_CT105_2013  \
# 0             10               2               0              22
# 1             10               0               0               4
# 2             64              14              40              16
# 3             22               2              24              16
# ...

# %%
# 'Unemployment Rate (disability)'
list_d = list(((df_merged_copy_new.iloc[1, 1:] + df_merged_copy_new.iloc[5, 1:]) / (df_merged_copy_new.iloc[0, 1:] + df_merged_copy_new.iloc[4, 1:])) * 100)
list_d.insert(0,'Unemployment Rate (disability)')

# %%
#'Unemployment Rate (no disability)'
list_nd = list(((df_merged_copy_new.iloc[3, 1:] + df_merged_copy_new.iloc[7, 1:]) / (df_merged_copy_new.iloc[2, 1:] + df_merged_copy_new.iloc[6, 1:])) * 100)
list_nd.insert(0,'Unemployment Rate (no disability)')

# %%
#Adding Unemployment rate (no disability)
df_merged_copy_new.loc[len(df_merged_copy_new)] = list_nd

#Adding Unemployment rate (disability)
df_merged_copy_new.loc[len(df_merged_copy_new)] = list_d

# %%
df_merged_copy_new
# Out:
#                                                Label  BG1_CT64_2013  \
# 0   In labor force: (disability below poverty level)       0.000000
# 1        Unemployed (disability below poverty level)       0.000000
# 2  In labor force: (no disability below poverty l...     119.000000
# 3     Unemployed (no disability below poverty level)      49.000000
# 4   In labor force: (disability above poverty level)      43.000000
# 5        Unemployed (disability above poverty level)       9.000000
# 6  In labor force: (no disability above poverty l...     140.000000
# 7     Unemployed (no disability above poverty level)       0.000000
# 8                  Unemployment Rate (no disability)      18.918919
# 9                     Unemployment Rate (disability)      20.930233
#
#    BG2_CT64_2013  BG1_CT102_2013  BG2_CT102_2013  BG1_CT105_2013  \
# 0      10.000000        2.000000        0.000000       22.000000
# 1      10.000000        0.000000        0.000000        4.000000
# ...

# %% [markdown]
# #### Census Track 64: Unemployment

# %%
#Census track 64
label_col_new = df_merged_copy_new.loc[:, 'Label']
ct64_cols_new = df_merged_copy_new.filter(regex='CT64')
df_ct64_employment = pd.concat([label_col_new, ct64_cols_new], axis=1)
#df_ct64_bp = df_ct64_bp.loc[1:2,:]
df_ct64_employment= df_ct64_employment.reset_index(drop=True)
df_ct64_employment
# Out:
#                                                Label  BG1_CT64_2013  \
# 0   In labor force: (disability below poverty level)       0.000000
# 1        Unemployed (disability below poverty level)       0.000000
# 2  In labor force: (no disability below poverty l...     119.000000
# 3     Unemployed (no disability below poverty level)      49.000000
# 4   In labor force: (disability above poverty level)      43.000000
# 5        Unemployed (disability above poverty level)       9.000000
# 6  In labor force: (no disability above poverty l...     140.000000
# 7     Unemployed (no disability above poverty level)       0.000000
# 8                  Unemployment Rate (no disability)      18.918919
# 9                     Unemployment Rate (disability)      20.930233
#
#    BG2_CT64_2013  BG1_CT64_2014  BG2_CT64_2014  BG1_CT64_2015  BG2_CT64_2015  \
# 0      10.000000       0.000000      11.000000       0.000000       9.000000
# ...

# %%
df_ct64_employment_numeric.filter(regex='BG1_CT64')
# Out:
#    BG1_CT64_2013  BG1_CT64_2014  BG1_CT64_2015  BG1_CT64_2016  BG1_CT64_2017  \
# 0       0.000000       0.000000       0.000000       0.000000        0.00000
# 1       0.000000       0.000000       0.000000       0.000000        0.00000
# 2     119.000000      93.000000     114.000000     138.000000      159.00000
# 3      49.000000      47.000000      89.000000      91.000000      102.00000
# 4      43.000000      15.000000      22.000000       0.000000        0.00000
# 5       9.000000       7.000000       8.000000       0.000000        0.00000
# 6     140.000000     180.000000     308.000000     344.000000      392.00000
# 7       0.000000       0.000000       0.000000       0.000000       37.00000
# 8      18.918919      17.216117      21.090047      18.879668       25.22686
# 9      20.930233      46.666667      36.363636            NaN            NaN
#
#    BG1_CT64_2018  BG1_CT64_2019  BG1_CT64_2020  BG1_CT64_2021
# ...

# %%
bg2_ct64_data_emp
# Out:
#    BG2_CT64_2013  BG2_CT64_2014  BG2_CT64_2015  BG2_CT64_2016  BG2_CT64_2017  \
# 0      10.000000      11.000000       9.000000      10.000000      29.000000
# 1      10.000000      11.000000       9.000000      10.000000      10.000000
# 2      64.000000      93.000000     101.000000      94.000000     124.000000
# 3      22.000000      36.000000      51.000000      44.000000      52.000000
# 4      52.000000      23.000000      17.000000      12.000000      16.000000
# 5      18.000000       0.000000       0.000000       0.000000       0.000000
# 6     355.000000     295.000000     234.000000     357.000000     289.000000
# 7      48.000000      33.000000       0.000000       7.000000       7.000000
# 8      16.706444      17.783505      15.223881      11.308204      14.285714
# 9      45.161290      32.352941      34.615385      45.454545      22.222222
#
#    BG2_CT64_2018  BG2_CT64_2019  BG2_CT64_2020  BG2_CT64_2021
# ...

# %%
df_ct64_employment_numeric = df_ct64_employment
df_ct64_employment_numeric = df_ct64_employment_numeric

# df_ct64_employment_numeric = df_ct64_employment.iloc[0:,1:].replace(',', '', regex=True).astype(int)#.drop(3).drop(0)
# df_ct64_employment_numeric = (df_ct64_employment_numeric.div(df_ct64_employment_numeric.sum(axis=0), axis=1)) * 100


bg1_ct64_data_emp = df_ct64_employment_numeric.filter(regex='BG1_CT64')
bg2_ct64_data_emp = df_ct64_employment_numeric.filter(regex='BG2_CT64')


# create a list of labels for the x-axis
years = list(range(2013, 2022))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10,10))

# plot the data for BG1_CT64
axs[0].plot(years, bg1_ct64_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[0].plot(years, bg1_ct64_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
# axs[0].plot(years, bg1_ct64_data_emp.loc[2], color='green', label='Employed (no disability above poverty level)')
# axs[0].plot(years, bg1_ct64_data_emp.loc[3], color='orange', label='Unemployed (no disability above poverty level)')
axs[0].set_title("Unemployment Rates Percentage Estimates by Disability in Block 1 Census Tract 64, DC (2013-2021)")
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years)
axs[0].legend()

# plot the data for BG2_CT64
axs[1].plot(years, bg2_ct64_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[1].plot(years, bg2_ct64_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
# axs[1].plot(years, bg2_ct64_data_emp.loc[2], color='green', label= 'Employed (no disability above poverty level)')
# axs[1].plot(years, bg2_ct64_data_emp.loc[3], color='orange', label= 'Unemployed (no disability above poverty level)')
#axs[1].set_title("Population Percentage Estimates by Disability Status and Poverty Level in Block 2 Census Tract 64, DC (2013-2021)")
axs[1].set_title("Unemployment Rates Percentage Estimates by Disability in Block 2 Census Tract 64, DC (2013-2021)")
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend()


# display the plot
plt.show()

# %% [markdown]
# #### Census Track 64: Poverty and Disability

# %%
# Define the list of labels to keep
labels_to_keep = ['Income in the past 12 months below poverty level:', 
                  'With a disability: (below poverty level)',
                  'No disability: (below poverty level)', 
                  'Income in the past 12 months at or above poverty level:', 
                  'With a disability: (above poverty level)', 
                  'No disability: (above poverty level)']

# Create a boolean mask based on the 'Label' column
mask = df_merged['Label'].isin(labels_to_keep)

# Filter the rows of df_merged using the mask
df_merged_new = df_merged[mask]

# %%
df_merged_new = df_merged_new.reset_index(drop=True)
df_merged_new
# Out:
#                                                Label  BG1_CT64_2013  \
# 0  Income in the past 12 months below poverty level:            391
# 1           With a disability: (below poverty level)            200
# 2               No disability: (below poverty level)            191
# 3  Income in the past 12 months at or above pover...            339
# 4           With a disability: (above poverty level)             87
# 5               No disability: (above poverty level)            252
#
#    BG2_CT64_2013  BG1_CT102_2013 BG2_CT102_2013 BG1_CT105_2013 BG2_CT105_2013  \
# 0            231              43             40            232             47
# 1            147               4              0             70              0
# 2             84              39             40            162             47
# 3            484             642          1,174          1,238          1,597
# 4             79               7             61            132             70
# ...

# %%
#Census track 64
label_col = df_merged_new.loc[:, 'Label']
ct64_cols = df_merged_new.filter(regex='CT64')
df_ct64_bp = pd.concat([label_col, ct64_cols], axis=1)
#df_ct64_bp = df_ct64_bp.loc[1:2,:]
df_ct64_bp
# Out:
#                                                Label  BG1_CT64_2013  \
# 0  Income in the past 12 months below poverty level:            391
# 1           With a disability: (below poverty level)            200
# 2               No disability: (below poverty level)            191
# 3  Income in the past 12 months at or above pover...            339
# 4           With a disability: (above poverty level)             87
# 5               No disability: (above poverty level)            252
#
#    BG2_CT64_2013  BG1_CT64_2014  BG2_CT64_2014  BG1_CT64_2015  BG2_CT64_2015  \
# 0            231            354            232            402            201
# 1            147            192            108            223             74
# 2             84            162            124            179            127
# 3            484            328            359            486            290
# 4             79             98             23             86             31
# ...

# %%
df_ct64_bp_numeric = df_ct64_bp.iloc[0:,1:].replace(',', '', regex=True).astype(int).drop(3).drop(0)
df_ct64_bp_numeric = (df_ct64_bp_numeric.div(df_ct64_bp_numeric.sum(axis=0), axis=1)) * 100

bg1_ct64_data = df_ct64_bp_numeric.filter(regex='BG1_CT64')
bg2_ct64_data = df_ct64_bp_numeric.filter(regex='BG2_CT64')


# create a list of labels for the x-axis
years = list(range(2013, 2022))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10,10))

# plot the data for BG1_CT64
axs[0].plot(years, bg1_ct64_data.loc[1:2].iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[0].plot(years, bg1_ct64_data.loc[2:2].iloc[0,:], color='blue', label='No disability: (below poverty level)')
axs[0].plot(years, bg1_ct64_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[0].plot(years, bg1_ct64_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[0].set_title("Population Percentage Estimates by Disability Status and Poverty Level in Block 1 Census Tract 64, DC (2013-2021)")
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years)
axs[0].legend()

# plot the data for BG2_CT64
axs[1].plot(years, bg2_ct64_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[1].plot(years, bg2_ct64_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[1].plot(years, bg2_ct64_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[1].plot(years, bg2_ct64_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[1].set_title("Population Percentage Estimates by Disability Status and Poverty Level in Block 2 Census Tract 64, DC (2013-2021)")
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend(fontsize= 6.4)


# display the plot
plt.show()

# %% [markdown]
# #### Census Track 102: Employment

# %%
#Census track 102
label_col_new = df_merged_copy_new.loc[:, 'Label']
ct102_cols_new = df_merged_copy_new.filter(regex='CT102')
df_ct102_employment = pd.concat([label_col_new, ct102_cols_new], axis=1)
df_ct102_employment= df_ct102_employment.reset_index(drop=True)
df_ct102_employment
# Out:
#                                                Label  BG1_CT102_2013  \
# 0   In labor force: (disability below poverty level)        2.000000
# 1        Unemployed (disability below poverty level)        0.000000
# 2  In labor force: (no disability below poverty l...       14.000000
# 3     Unemployed (no disability below poverty level)        2.000000
# 4   In labor force: (disability above poverty level)        7.000000
# 5        Unemployed (disability above poverty level)        0.000000
# 6  In labor force: (no disability above poverty l...      515.000000
# 7     Unemployed (no disability above poverty level)       15.000000
# 8                  Unemployment Rate (no disability)        3.213611
# 9                     Unemployment Rate (disability)        0.000000
#
#    BG2_CT102_2013  BG1_CT102_2014  BG2_CT102_2014  BG1_CT102_2015  \
# 0        0.000000        1.000000        0.000000        1.000000
# 1        0.000000        0.000000        0.000000        0.000000
# ...

# %%
bg1_ct102_data_emp
# Out:
#    BG1_CT102_2013  BG1_CT102_2014  BG1_CT102_2015  BG1_CT102_2016  \
# 0        2.000000        1.000000        1.000000        1.000000
# 1        0.000000        0.000000        0.000000        0.000000
# 2       14.000000       14.000000       19.000000       11.000000
# 3        2.000000        2.000000        1.000000        1.000000
# 4        7.000000        5.000000        7.000000        6.000000
# 5        0.000000        0.000000        0.000000        0.000000
# 6      515.000000      500.000000      506.000000      514.000000
# 7       15.000000       20.000000       27.000000       27.000000
# 8        3.213611        4.280156        5.333333        5.333333
# 9        0.000000        0.000000        0.000000        0.000000
#
#    BG1_CT102_2017  BG1_CT102_2018  BG1_CT102_2019
# 0        0.000000        0.000000        0.000000
# 1        0.000000        0.000000        0.000000
# 2       49.000000       36.000000       32.000000
# ...

# %%
# df_ct102_employment_numeric = df_ct102_employment.iloc[0:,1:].replace(',', '', regex=True).astype(int)#.drop(3).drop(0)
# df_ct102_employment_numeric = (df_ct102_employment_numeric.div(df_ct102_employment_numeric.sum(axis=0), axis=1)) * 100

df_ct102_employment_numeric = df_ct102_employment

bg1_ct102_data_emp = df_ct102_employment_numeric.filter(regex='BG1_CT102')
bg2_ct102_data_emp = df_ct102_employment_numeric.filter(regex='BG2_CT102')


# create a list of labels for the x-axis
years = list(range(2013, 2020))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10,10))

# plot the data for BG1_CT102
axs[0].plot(years, bg1_ct102_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[0].plot(years, bg1_ct102_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
axs[0].set_title("Unemployment Rates Percentage Estimates by Disability in Block 1 Census Tract 102, DC (2013-2019)")
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years)
axs[0].legend()



# plot the data for BG2_CT102
axs[1].plot(years, bg2_ct102_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[1].plot(years, bg2_ct102_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
#axs[1].set_title("Population Percentage Estimates by Disability Status and Poverty Level in Block 2 Census Tract 64, DC (2013-2021)")
axs[1].set_title("Unemployment Rates Percentage Estimates by Disability in Block 2 Census Tract 102, DC (2013-2019)")
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend()


# display the plot
plt.show()

# %% [markdown]
# #### Census Track 102: Poverty and Disability

# %%
#Census track 102
label_col = df_merged_new.loc[:, 'Label']
ct102_cols = df_merged_new.filter(regex='CT102')
df_ct102_bp = pd.concat([label_col, ct102_cols], axis=1)
#df_ct102_bp = df_ct102_bp.loc[1:2,:]
df_ct102_bp
# Out:
#                                                Label  BG1_CT102_2013  \
# 0  Income in the past 12 months below poverty level:              43
# 1           With a disability: (below poverty level)               4
# 2               No disability: (below poverty level)              39
# 3  Income in the past 12 months at or above pover...             642
# 4           With a disability: (above poverty level)               7
# 5               No disability: (above poverty level)             635
#
#   BG2_CT102_2013  BG1_CT102_2014 BG2_CT102_2014  BG1_CT102_2015  \
# 0             40              39             54              42
# 1              0               5              0               1
# 2             40              34             54              41
# 3          1,174             627          1,170             643
# 4             61              13             41              16
# 5          1,113             614          1,129             627
#
# ...

# %%
df_ct102_bp_numeric = df_ct102_bp.iloc[0:,1:].replace(',', '', regex=True).astype(int).drop(3).drop(0)
df_ct102_bp_numeric = (df_ct102_bp_numeric.div(df_ct102_bp_numeric.sum(axis=0), axis=1)) * 100


bg1_ct102_data = df_ct102_bp_numeric.filter(regex='BG1_CT102')
bg2_ct102_data = df_ct102_bp_numeric.filter(regex='BG2_CT102')

# create a list of labels for the x-axis
years = list(range(2013, 2020))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10,10))

# plot the data for BG1_CT102
axs[0].plot(years, bg1_ct102_data.loc[1:2].iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[0].plot(years, bg1_ct102_data.loc[2:2].iloc[0,:], color='blue', label='No disability: (below poverty level)')
axs[0].plot(years, bg1_ct102_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[0].plot(years, bg1_ct102_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[0].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 1 Census Tract 102, DC (2013-2019)')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years)
axs[0].legend()


# plot the data for BG2_CT102
axs[1].plot(years, bg2_ct102_data.loc[0:1].iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[1].plot(years, bg2_ct102_data.loc[1:2].iloc[0,:], color='blue', label='No disability: (below poverty level)')
axs[1].plot(years, bg2_ct102_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[1].plot(years, bg2_ct102_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[1].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 2 Census Tract 102, DC (2013-2019)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend()


# display the plot
plt.show()

# %% [markdown]
# #### Census Track 110: Employment

# %%
#Census track 110
label_col_new = df_merged_copy_new.loc[:, 'Label']
ct110_cols_new = df_merged_copy_new.filter(regex='CT110')
df_ct110_employment = pd.concat([label_col_new, ct110_cols_new], axis=1)
df_ct110_employment= df_ct110_employment.reset_index(drop=True)
df_ct110_employment
# Out:
#                                                Label  BG1_CT110_2013  \
# 0   In labor force: (disability below poverty level)        0.000000
# 1        Unemployed (disability below poverty level)        0.000000
# 2  In labor force: (no disability below poverty l...        0.000000
# 3     Unemployed (no disability below poverty level)        0.000000
# 4   In labor force: (disability above poverty level)       15.000000
# 5        Unemployed (disability above poverty level)        0.000000
# 6  In labor force: (no disability above poverty l...      377.000000
# 7     Unemployed (no disability above poverty level)       13.000000
# 8                  Unemployment Rate (no disability)        3.448276
# 9                     Unemployment Rate (disability)        0.000000
#
#    BG2_CT110_2013  BG3_CT110_2013  BG4_CT110_2013  BG1_CT110_2014  \
# 0        0.000000        0.000000        0.000000        0.000000
# 1        0.000000        0.000000        0.000000        0.000000
# ...

# %%
bg4_ct110_data_emp.loc[9]
# Out:
# BG4_CT110_2013    0.0
# BG4_CT110_2014    0.0
# BG4_CT110_2015    0.0
# BG4_CT110_2016    0.0
# BG4_CT110_2017    0.0
# BG4_CT110_2018    0.0
# BG4_CT110_2019    0.0
# Name: 9, dtype: float64

# %%
df_ct110_employment_numeric = df_ct110_employment

bg1_ct110_data_emp = df_ct110_employment_numeric.filter(regex='BG1_CT110')
bg2_ct110_data_emp = df_ct110_employment_numeric.filter(regex='BG2_CT110')
bg3_ct110_data_emp = df_ct110_employment_numeric.filter(regex='BG3_CT110')
bg4_ct110_data_emp = df_ct110_employment_numeric.filter(regex='BG4_CT110')


# create a list of labels for the x-axis
years = list(range(2013, 2020))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10,20))

# plot the data for BG1_CT110
axs[0].plot(years, bg1_ct110_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[0].plot(years, bg1_ct110_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
axs[0].set_title("Unemployment Rates Percentage Estimates by Disability in Block 1 Census Tract 110, DC (2013-2019)")
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years)
axs[0].legend()


# plot the data for BG2_CT110
axs[1].plot(years, bg2_ct110_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[1].plot(years, bg2_ct110_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
axs[1].set_title("Unemployment Rates Percentage Estimates by Disability in Block 2 Census Tract 110, DC (2013-2019)")
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend()


# plot the data for BG3_CT110
axs[2].plot(years, bg3_ct110_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[2].plot(years, bg3_ct110_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
axs[2].set_title("Unemployment Rates Percentage Estimates by Disability in Block 3 Census Tract 110, DC (2013-2019)")
axs[2].set_xlabel('Year')
axs[2].set_ylabel('Population percentage')
axs[2].set_xticks(years)
axs[2].legend()

# plot the data for BG4_CT110
axs[3].plot(years, [int(x) for x in list(bg4_ct110_data_emp.loc[8])], color='red', label='With a disability: (below poverty level)')
axs[3].plot(years, [int(x) for x in list(bg4_ct110_data_emp.loc[9])], color='blue', label='No disability: (below poverty level)')
axs[3].set_title("Unemployment Rates Percentage Estimates by Disability in Block 4 Census Tract 110, DC (2013-2019)")
axs[3].set_xlabel('Year')
axs[3].set_ylabel('Population percentage')
axs[3].set_xticks(years)
axs[3].legend()

# display the plot
plt.show()

# %% [markdown]
# #### Census Track 110: Poverty and Disability

# %%
#Census track 110
label_col = df_merged_new.loc[:, 'Label']
ct110_cols = df_merged_new.filter(regex='CT110')
df_ct110_bp = pd.concat([label_col, ct110_cols], axis=1)
# df_ct110_bp = df_ct110_bp.loc[1:2,:]
df_ct110_bp
# Out:
#                                                Label  BG1_CT110_2013  \
# 0  Income in the past 12 months below poverty level:               0
# 1           With a disability: (below poverty level)               0
# 2               No disability: (below poverty level)               0
# 3  Income in the past 12 months at or above pover...             392
# 4           With a disability: (above poverty level)              15
# 5               No disability: (above poverty level)             377
#
#    BG2_CT110_2013  BG3_CT110_2013 BG4_CT110_2013  BG1_CT110_2014  \
# 0              82               0             36               0
# 1               0               0              0               0
# 2              82               0             36               0
# 3             304             469            988             466
# 4              10               0             90               0
# 5             294             469            898             466
#
# ...

# %%
df_ct110_bp_numeric = df_ct110_bp.iloc[0:,1:].replace(',', '', regex=True).astype(int).drop(3).drop(0)
df_ct110_bp_numeric = (df_ct110_bp_numeric.div(df_ct110_bp_numeric.sum(axis=0), axis=1)) * 100

# separate the data for each block group
bg1_ct110_data = df_ct110_bp_numeric.filter(regex='BG1_CT110')#.loc[1:2]
bg2_ct110_data = df_ct110_bp_numeric.filter(regex='BG2_CT110')#.loc[1:2]
bg3_ct110_data = df_ct110_bp_numeric.filter(regex='BG3_CT110')#.loc[1:2]
bg4_ct110_data = df_ct110_bp_numeric.filter(regex='BG4_CT110')#.loc[1:2]

# %%
# create a list of labels for the x-axis
years = list(range(2013, 2020))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10,20))

# plot the data for BG1_CT110
axs[0].plot(years, bg1_ct110_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[0].plot(years, bg1_ct110_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[0].plot(years, bg1_ct110_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[0].plot(years, bg1_ct110_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[0].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 1 Census Tract 110, DC (2013-2019)')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years)
axs[0].legend()


# plot the data for BG2_CT110
axs[1].plot(years, bg2_ct110_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[1].plot(years, bg2_ct110_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[1].plot(years, bg2_ct110_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[1].plot(years, bg2_ct110_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[1].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 2 Census Tract 110, DC (2013-2019)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend()


# plot the data for BG3_CT110
axs[2].plot(years, bg3_ct110_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[2].plot(years, bg3_ct110_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[2].plot(years, bg3_ct110_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[2].plot(years, bg3_ct110_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[2].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 3 Census Tract 110, DC (2013-2019)')
axs[2].set_xlabel('Year')
axs[2].set_ylabel('Population percentage')
axs[2].set_xticks(years)
axs[2].legend()

# plot the data for BG4_CT110
axs[3].plot(years, [int(x) for x in list(bg4_ct110_data.iloc[0,:])], color='red', label='With a disability: (below poverty level)')
axs[3].plot(years, [int(x) for x in list(bg4_ct110_data.iloc[1,:])], color='blue', label='No disability: (below poverty level)')
axs[3].plot(years, [int(x) for x in list(bg4_ct110_data.loc[4:4].iloc[0,:])], color='green', label='With a disability: (above poverty level)')
axs[3].plot(years, [int(x) for x in list(bg4_ct110_data.loc[5:].iloc[0,:])], color='orange', label='No disability: (above poverty level)')
axs[3].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 4 Census Tract 110, DC (2013-2019)')
axs[3].set_xlabel('Year')
axs[3].set_ylabel('Population percentage')
axs[3].set_xticks(years)
axs[3].legend()

# display the plot
plt.show()

# %% [markdown]
# #### Census Track 105: Employment

# %%
#Census track 105
label_col_new = df_merged_copy_new.loc[:, 'Label']
ct105_cols_new = df_merged_copy_new.filter(regex='CT105')
df_ct105_employment = pd.concat([label_col_new, ct105_cols_new], axis=1)
df_ct105_employment= df_ct105_employment.reset_index(drop=True)
df_ct105_employment
# Out:
#                                                Label  BG1_CT105_2013  \
# 0   In labor force: (disability below poverty level)       22.000000
# 1        Unemployed (disability below poverty level)        4.000000
# 2  In labor force: (no disability below poverty l...       16.000000
# 3     Unemployed (no disability below poverty level)       16.000000
# 4   In labor force: (disability above poverty level)       49.000000
# 5        Unemployed (disability above poverty level)       14.000000
# 6  In labor force: (no disability above poverty l...     1042.000000
# 7     Unemployed (no disability above poverty level)       21.000000
# 8                  Unemployment Rate (no disability)        3.497164
# 9                     Unemployment Rate (disability)       25.352113
#
#    BG2_CT105_2013  BG1_CT105_2014  BG2_CT105_2014  BG1_CT105_2015  \
# 0        0.000000        2.000000        0.000000        3.000000
# 1        0.000000        2.000000        0.000000        3.000000
# ...

# %%
# df_ct105_employment_numeric = df_ct105_employment.iloc[0:,1:].replace(',', '', regex=True).astype(int)#.drop(3).drop(0)
# df_ct105_employment_numeric = (df_ct105_employment.div(df_ct105_employment_numeric.sum(axis=0), axis=1)) * 100

# separate the data for each block group
bg1_ct105_data_emp = df_ct105_employment_numeric.filter(regex='BG1_CT105')#.loc[1:2]
bg2_ct105_data_emp = df_ct105_employment_numeric.filter(regex='BG2_CT105')#.loc[1:2]
bg3_ct105_data_emp = df_ct105_employment_numeric.filter(regex='BG3_CT105')#.loc[1:2]
bg4_ct105_data_emp = df_ct105_employment_numeric.filter(regex='BG4_CT105')#.loc[1:2]
bg5_ct105_data_emp = df_ct105_employment_numeric.filter(regex='BG5_CT105')#.loc[1:2]

# %%
bg1_ct105_data_emp
# Out:
#    BG1_CT105_2013  BG1_CT105_2014  BG1_CT105_2015  BG1_CT105_2016  \
# 0       22.000000        2.000000        3.000000             0.0
# 1        4.000000        2.000000        3.000000             0.0
# 2       16.000000       39.000000       42.000000            74.0
# 3       16.000000       18.000000       17.000000            33.0
# 4       49.000000       18.000000       35.000000            28.0
# 5       14.000000       18.000000       35.000000             0.0
# 6     1042.000000      904.000000      863.000000           826.0
# 7       21.000000       53.000000       65.000000            48.0
# 8        3.497164        7.529162        9.060773             9.0
# 9       25.352113      100.000000      100.000000             0.0
#
#    BG1_CT105_2017  BG1_CT105_2018  BG1_CT105_2019  BG1_CT105_2020  \
# 0        0.000000        0.000000        0.000000             NaN
# 1        0.000000        0.000000        0.000000             NaN
# ...

# %%
# create a list of labels for the x-axis
years = list(range(2013, 2022))
years_1 = list(range(2013,2020))
years_2 = list(range(2020, 2022))
years_3 = list(range(2013, 2020))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10,25))


# plot the data for BG1_CT105
axs[0].plot(years_3, bg1_ct105_data_emp.loc[8].iloc[0:7], color='red', label= 'Unemployment Rate (no disability)')
axs[0].plot(years_3, bg1_ct105_data_emp.loc[9].iloc[0:7], color='blue', label= 'Unemployment Rate (disability)')
axs[0].set_title("Unemployment Rates Percentage Estimates by Disability in Block 1 Census Tract 105, DC (2013-2019)")
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years_3)
axs[0].legend()

# plot the data for BG2_CT105
axs[1].plot(years, bg2_ct105_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[1].plot(years, bg2_ct105_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
axs[1].set_title("Unemployment Rates Percentage Estimates by Disability in Block 2 Census Tract 105, DC (2013-2021)")
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend()

# plot the data for BG3_CT105
axs[2].plot(years_2, bg3_ct105_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[2].plot(years_2, bg3_ct105_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
axs[2].set_title("Unemployment Rates Percentage Estimates by Disability in Block 3 Census Tract 105, DC (2020-2021)")
axs[2].set_xlabel('Year')
axs[2].set_ylabel('Population percentage')
axs[2].set_xticks(years_2)
axs[2].legend()


# plot the data for BG5_CT105
axs[3].plot(years_2, bg5_ct105_data_emp.loc[8], color='red', label= 'Unemployment Rate (no disability)')
axs[3].plot(years_2, bg5_ct105_data_emp.loc[9], color='blue', label= 'Unemployment Rate (disability)')
axs[3].set_title("Unemployment Rates Percentage Estimates by Disability in Block 5 Census Tract 105, DC (2020-2021)")
axs[3].set_xlabel('Year')
axs[3].set_ylabel('Population percentage')
axs[3].set_xticks(years_2)
axs[3].legend()




plt.show()

# %% [markdown]
# #### Census Track 105: Poverty and disability

# %%
#Census track 105
label_col = df_merged_new.loc[:, 'Label']
ct105_cols = df_merged_new.filter(regex='CT105')
df_ct105_bp = pd.concat([label_col, ct105_cols], axis=1)
#df_ct105_bp = df_ct105_bp.loc[1:2,:]
df_ct105_bp
# Out:
#                                                Label BG1_CT105_2013  \
# 0  Income in the past 12 months below poverty level:            232
# 1           With a disability: (below poverty level)             70
# 2               No disability: (below poverty level)            162
# 3  Income in the past 12 months at or above pover...          1,238
# 4           With a disability: (above poverty level)            132
# 5               No disability: (above poverty level)          1,106
#
#   BG2_CT105_2013 BG1_CT105_2014 BG2_CT105_2014 BG1_CT105_2015 BG2_CT105_2015  \
# 0             47            200             95            238            119
# 1              0             56             21             34             29
# 2             47            144             74            204             90
# 3          1,597          1,030          1,551          1,029          1,470
# 4             70             63             31            134             89
# ...

# %%
df_ct105_bp_numeric = df_ct105_bp.iloc[0:,1:].replace(',', '', regex=True).astype(int).drop(3).drop(0)
df_ct105_bp_numeric = (df_ct105_bp_numeric.div(df_ct105_bp_numeric.sum(axis=0), axis=1)) * 100

# separate the data for each block group
bg1_ct105_data = df_ct105_bp_numeric.filter(regex='BG1_CT105')#.loc[1:2]
bg2_ct105_data = df_ct105_bp_numeric.filter(regex='BG2_CT105')#.loc[1:2]
bg3_ct105_data = df_ct105_bp_numeric.filter(regex='BG3_CT105')#.loc[1:2]
bg4_ct105_data = df_ct105_bp_numeric.filter(regex='BG4_CT105')#.loc[1:2]
bg5_ct105_data = df_ct105_bp_numeric.filter(regex='BG5_CT105')#.loc[1:2]

# %%
# create a list of labels for the x-axis
years = list(range(2013, 2022))
years_1 = list(range(2013,2020))
years_2 = list(range(2020, 2022))

# create a figure and axis objects
fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(10,25))

# plot the data for BG1_CT105
axs[0].plot(years, bg1_ct105_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[0].plot(years, bg1_ct105_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[0].plot(years, bg1_ct105_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[0].plot(years, bg1_ct105_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[0].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 1 Census Tract 105, DC (2013-2019)')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Population percentage')
axs[0].set_xticks(years_1)
axs[0].legend()




# plot the data for BG2_CT105
axs[1].plot(years, bg2_ct105_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[1].plot(years, bg2_ct105_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[1].plot(years, bg2_ct105_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[1].plot(years, bg2_ct105_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[1].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 2 Census Tract 105, DC (2013-2021)')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('Population percentage')
axs[1].set_xticks(years)
axs[1].legend()


# plot the data for BG3_CT105
axs[2].plot(years_2, bg3_ct105_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[2].plot(years_2, bg3_ct105_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[2].plot(years_2, bg3_ct105_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[2].plot(years_2, bg3_ct105_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[2].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 3 Census Tract 105, DC (2020-2021)')
axs[2].set_xlabel('Year')
axs[2].set_ylabel('Population percentage')
axs[2].set_xticks(years_2)
axs[2].legend()

# plot the data for BG5_CT105
axs[3].plot(years_2, bg5_ct105_data.iloc[0,:], color='red', label='With a disability: (below poverty level)')
axs[3].plot(years_2, bg5_ct105_data.iloc[1,:], color='blue', label='No disability: (below poverty level)')
axs[3].plot(years_2, bg5_ct105_data.loc[4:4].iloc[0,:], color='green', label='With a disability: (above poverty level)')
axs[3].plot(years_2, bg5_ct105_data.loc[5:].iloc[0,:], color='orange', label='No disability: (above poverty level)')
axs[3].set_title('Population Percentage Estimates by Disability Status and Poverty Level in Block 5 Census Tract 105, DC (2020-2021)')
axs[3].set_xlabel('Year')
axs[3].set_ylabel('Population percentage')
axs[3].set_xticks(years_2)
axs[3].legend()

plt.show()
